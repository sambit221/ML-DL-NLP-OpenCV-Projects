# %% [markdown]
# <h1 align='center' style='color:purple'><b>Decision Trees - Part 1</b></h1>

# %% [markdown]
# A decision tree follows tree-like model of decisions and their possible outcomes. It is a way to represent an algorithm that only contains conditional control statements.
# It a flowchart-like structure. Each internal node represents a "test" on a feature whereas every branch represents the outcome of the test, & each terminal/leaf node represents the outcome which can be a continuous value or class label for regression and classification problem respectively.
#  - It is a Supervised Learning Algorithm.
#  - it can be used for both classification and regression problems.
#  - It can also handle non-linear data which was not possible in case of linear models
#
# Advantages :
#  - Simple and easy to understand and visualize
#  - Somewhat resistant to outliers
#  - No Feature Scaling is Required.
#
# Disadvantages :
#  - Overfitting
#  - High variance
#  - Not suitable for large Datasets

# %% [markdown]
# <b>Load the data that we will be using to train our model</b>
#
# Here we are using Titanic dataset which contains the data from one of the most infamous shipwrecks in history : The sinking of the Titanic.

# %% [markdown]
# <b> Import Necessary Libraries</b>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# <b>Get the data<b/>

# %%
import pandas as pd 
import io 

df = pd.read_csv('titanic.csv',index_col=0) 
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# <b>Data Dictionary</b>
#
# ##### Variable	& Definition
#  - Survived (Target) :	Survival of passenger	(0 = No, 1 = Yes)
#  - Pclass : Ticket class	(1 = 1st, 2 = 2nd, 3 = 3rd)
#  - Sex : Gender
#  - Age : Age in years
#  - Sibsp :	# of siblings / spouses aboard the Titanic
#  - Parch : # of parents / children aboard the Titanic
#  - Ticket :	Ticket number
#  - Fare :	Passenger fare
#  - Cabin : Cabin number
#  - Embarked :	Port of Embarkation	(C = Cherbourg, Q = Queenstown, S =  Southampton)

# %% [markdown]
# <b>Drop insignificant Variables<b/>

# %%
df.drop(['Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)

# %% [markdown]
# As a person's survival may not depend on these variables.

# %%
df.head()
# Out:
#              Survived  Pclass     Sex   Age     Fare
# PassengerId
# 1                   0       3    male  22.0   7.2500
# 2                   1       1  female  38.0  71.2833
# 3                   1       3  female  26.0   7.9250
# 4                   1       1  female  35.0  53.1000
# 5                   0       3    male  35.0   8.0500

# %% [markdown]
# <b>Separate Inputs and Target</b>

# %%
inputs = df.drop('Survived',axis='columns')
target = df.Survived

# %% [markdown]
# <b>Encode Categorical Variables 'Sex', as decision trees implemented in scikit-learn accepts numerical variables only.</b>

# %%
inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# PassengerId
# 1     22.0
# 2     38.0
# 3     26.0
# 4     35.0
# 5     35.0
# 6      NaN
# 7     54.0
# 8      2.0
# 9     27.0
# 10    14.0
# Name: Age, dtype: float64

# %% [markdown]
# <b>We can see that there are a few NaN values in Age. So we will  fill those missing values with the avergae age.</b>

# %%
inputs.Age = inputs.Age.fillna(inputs.Age.mean())

# %%
# print first 10 records
inputs.Age[:10]
# Out:
# PassengerId
# 1     22.000000
# 2     38.000000
# 3     26.000000
# 4     35.000000
# 5     35.000000
# 6     29.699118
# 7     54.000000
# 8      2.000000
# 9     27.000000
# 10    14.000000
# Name: Age, dtype: float64

# %% [markdown]
# The age of Passenger number 6 has been filled with the average age(29.699).

# %% [markdown]
# <b>Separate Training and Testing Data</b>

# %%
# import train_test_split from sklearn library
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %% [markdown]
# Here test_size is used to specify test data size. 0.3 means 30% of data will be used for test data & remaining 70% will be used for training data.
#  X_train, y_train : inputs and target of training data
#  X_test, y_test : inputs and target of testing data

# %% [markdown]
# <b> Check the length of Traing and Testing Data</b>

# %%
print('Length of Training Data : {} that is 70% of original data.'.format(len(X_train)))
print('Length of Testing Data : {} that is 30% of original data.'.format(len(X_test)))
# Out:
# Length of Training Data : 623 that is 70% of original data.
# Length of Testing Data : 268 that is 30% of original data.

# %% [markdown]
# <b>Import Decision Tree Classifier</b>
# In this project, our target variable is of binary data type. So a Classification model will be used.

# %%
from sklearn import tree

# initialize a Decision Tree classifier model.
model = tree.DecisionTreeClassifier()

# %% [markdown]
# <b>Model Training</b> : Fitting/Training a model means that you're making your model learn the relationship b/w predictors and target so that you can predict the future values of the target.

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# <b>After model training, make predictions for that testing data.</b>

# %%
model_accuracy = model.score(X_test,y_test)
print('Print model accuracy =',round(model_accuracy,3))


from sklearn.metrics import accuracy_score
Y_train_predict=model.predict(X_train)
print(accuracy_score(y_train,Y_train_predict))
# Out:
# Print model accuracy = 0.739
# 0.9935794542536116

# %% [markdown]
# model.score(X_test,ytest) : This function takes a feature matrix X_test and the expected target values y_test. Then y_testis compared with thet Predictions for X_test & either accuracy (for classification) or R2 score (for regression) is returned.

# %% [markdown]
# <b> Plot Decision Tree </b>

# %%
# Initialize a figure and use figsize to control the size of the rendered image.
plt.figure(figsize=(120,110))

# Plot Decision tree
tree.plot_tree(model, filled=True)

#Here filled is boolean parameter (default value = False) When set to True, 
#it paints the decisiontree nodes to indicate majority class for classification problem.
# Out:
# [Text(3097.8169878563886, 5830.110000000001, 'X[1] <= 1.5\ngini = 0.474\nsamples = 623\nvalue = [383, 240]'),
#  Text(1120.603352692714, 5531.13, 'X[2] <= 12.5\ngini = 0.303\nsamples = 398\nvalue = [324, 74]'),
#  Text(318.18373812038016, 5232.150000000001, 'X[0] <= 2.5\ngini = 0.476\nsamples = 23\nvalue = [9, 14]'),
#  Text(261.6177402323126, 4933.17, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(374.74973600844777, 4933.17, 'X[3] <= 20.825\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(318.18373812038016, 4634.1900000000005, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(431.3157338965153, 4634.1900000000005, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(1923.0229672650476, 5232.150000000001, 'X[0] <= 1.5\ngini = 0.269\nsamples = 375\nvalue = [315, 60]'),
#  Text(742.4287222808871, 4933.17, 'X[2] <= 53.0\ngini = 0.459\nsamples = 84\nvalue = [54, 30]'),
#  Text(544.4477296726506, 4634.1900000000005, 'X[3] <= 25.938\ngini = 0.49\nsamples = 63\nvalue = [36, 27]'),
#  Text(487.88173178458294, 4335.21, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(601.013727560718, 4335.21, 'X[3] <= 27.135\ngini = 0.498\nsamples = 58\nvalue = [31, 27]'),
#  Text(487.88173178458294, 4036.2300000000005, 'X[2] <= 32.35\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(431.3157338965153, 3737.25, 'X[2] <= 28.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(374.74973600844777, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(487.88173178458294, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(544.4477296726506, 3737.25, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(714.1457233368533, 4036.2300000000005, 'X[3] <= 379.925\ngini = 0.475\nsamples = 49\nvalue = [30, 19]'),
#  Text(657.5797254487857, 3737.25, 'X[3] <= 134.642\ngini = 0.462\nsamples = 47\nvalue = [30, 17]'),
#  Text(601.013727560718, 3438.2700000000004, 'X[3] <= 109.892\ngini = 0.482\nsamples = 42\nvalue = [25, 17]'),
#  Text(544.4477296726506, 3139.29, 'X[3] <= 77.79\ngini = 0.46\nsamples = 39\nvalue = [25, 14]'),
#  Text(353.5374868004224, 2840.3100000000004, 'X[2] <= 28.85\ngini = 0.491\nsamples = 30\nvalue = [17, 13]'),
#  Text(296.9714889123548, 2541.33, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(410.10348468848997, 2541.33, 'X[2] <= 47.5\ngini = 0.453\nsamples = 26\nvalue = [17, 9]'),
#  Text(197.98099260823653, 2242.3500000000004, 'X[3] <= 29.1\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(141.41499472016898, 1943.37, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(254.54699049630415, 1943.37, 'X[3] <= 30.75\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(113.13199577613517, 1644.3900000000003, 'X[2] <= 34.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(56.565997888067585, 1345.4099999999999, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(169.69799366420276, 1345.4099999999999, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(395.96198521647307, 1644.3900000000003, 'X[3] <= 52.277\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(282.82998944033795, 1345.4099999999999, 'X[3] <= 37.55\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(226.26399155227034, 1046.4300000000003, 'X[3] <= 35.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(169.69799366420276, 747.4499999999998, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(282.82998944033795, 747.4499999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(339.3959873284055, 1046.4300000000003, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(509.0939809926083, 1345.4099999999999, 'X[3] <= 52.827\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(452.5279831045407, 1046.4300000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(565.6599788806759, 1046.4300000000003, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(622.2259767687434, 2242.3500000000004, 'X[3] <= 56.415\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(565.6599788806759, 1943.37, 'X[3] <= 43.2\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(509.0939809926083, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(622.2259767687434, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(678.791974656811, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(735.3579725448786, 2840.3100000000004, 'X[2] <= 47.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(678.791974656811, 2541.33, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(791.9239704329461, 2541.33, 'X[2] <= 49.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(735.3579725448786, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(848.4899683210137, 2242.3500000000004, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(657.5797254487857, 3139.29, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(714.1457233368533, 3438.2700000000004, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(770.7117212249209, 3737.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(940.4097148891236, 4634.1900000000005, 'X[2] <= 75.5\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(883.843717001056, 4335.21, 'X[3] <= 35.077\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(827.2777191129884, 4036.2300000000005, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(940.4097148891236, 4036.2300000000005, 'X[3] <= 42.502\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(883.843717001056, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(996.9757127771912, 3737.25, 'X[3] <= 78.244\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(940.4097148891236, 3438.2700000000004, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(1053.5417106652587, 3438.2700000000004, 'X[3] <= 96.237\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(996.9757127771912, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1110.1077085533263, 3139.29, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(996.9757127771912, 4335.21, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3103.617212249208, 4933.17, 'X[2] <= 32.5\ngini = 0.185\nsamples = 291\nvalue = [261, 30]'),
#  Text(2452.6663146779306, 4634.1900000000005, 'X[2] <= 31.5\ngini = 0.214\nsamples = 221\nvalue = [194, 27]'),
#  Text(1829.556494192186, 4335.21, 'X[2] <= 17.5\ngini = 0.194\nsamples = 211\nvalue = [188, 23]'),
#  Text(1772.9904963041183, 4036.2300000000005, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(1886.1224920802536, 4036.2300000000005, 'X[2] <= 20.25\ngini = 0.208\nsamples = 195\nvalue = [172, 23]'),
#  Text(1477.7866948257656, 3737.25, 'X[3] <= 7.91\ngini = 0.328\nsamples = 29\nvalue = [23, 6]'),
#  Text(1279.8057022175292, 3438.2700000000004, 'X[2] <= 19.5\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(1223.2397043294616, 3139.29, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(1336.3717001055968, 3139.29, 'X[3] <= 7.14\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(1279.8057022175292, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1392.9376979936642, 2840.3100000000004, 'X[3] <= 7.542\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1336.3717001055968, 2541.33, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1449.5036958817318, 2541.33, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1675.7676874340023, 3438.2700000000004, 'X[3] <= 8.104\ngini = 0.401\nsamples = 18\nvalue = [13, 5]'),
#  Text(1562.635691657867, 3139.29, 'X[2] <= 18.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(1506.0696937697994, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1619.2016895459346, 2840.3100000000004, 'X[3] <= 7.988\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(1562.635691657867, 2541.33, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1675.7676874340023, 2541.33, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1788.8996832101375, 3139.29, 'X[3] <= 10.335\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(1732.3336853220699, 2840.3100000000004, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1845.4656810982049, 2840.3100000000004, 'X[2] <= 19.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(1788.8996832101375, 2541.33, 'X[3] <= 11.75\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(1732.3336853220699, 2242.3500000000004, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(1845.4656810982049, 2242.3500000000004, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(1902.0316789862725, 2541.33, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2294.4582893347415, 3737.25, 'X[3] <= 7.227\ngini = 0.184\nsamples = 166\nvalue = [149, 17]'),
#  Text(2071.729672650475, 3438.2700000000004, 'X[2] <= 28.35\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(2015.1636747624077, 3139.29, 'X[3] <= 7.013\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(1958.59767687434, 2840.3100000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2071.729672650475, 2840.3100000000004, 'X[3] <= 7.133\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(2015.1636747624077, 2541.33, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2128.2956705385427, 2541.33, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2128.2956705385427, 3139.29, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(2517.1869060190074, 3438.2700000000004, 'X[2] <= 28.75\ngini = 0.16\nsamples = 148\nvalue = [135, 13]'),
#  Text(2241.427666314678, 3139.29, 'X[2] <= 24.5\ngini = 0.06\nsamples = 65\nvalue = [63, 2]'),
#  Text(2184.8616684266103, 2840.3100000000004, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(2297.9936642027455, 2840.3100000000004, 'X[2] <= 26.5\ngini = 0.121\nsamples = 31\nvalue = [29, 2]'),
#  Text(2241.427666314678, 2541.33, 'X[3] <= 16.621\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(2128.2956705385427, 2242.3500000000004, 'X[3] <= 7.815\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(2071.729672650475, 1943.37, 'X[3] <= 7.758\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(2015.1636747624077, 1644.3900000000003, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2128.2956705385427, 1644.3900000000003, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(2184.8616684266103, 1943.37, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(2354.559662090813, 2242.3500000000004, 'X[3] <= 19.681\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(2297.9936642027455, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2411.125659978881, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2354.559662090813, 2541.33, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(2792.946145723337, 3139.29, 'X[2] <= 29.35\ngini = 0.23\nsamples = 83\nvalue = [72, 11]'),
#  Text(2524.257655755016, 2840.3100000000004, 'X[3] <= 7.973\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(2467.6916578669484, 2541.33, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2580.8236536430836, 2541.33, 'X[3] <= 8.775\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(2524.257655755016, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2637.3896515311512, 2242.3500000000004, 'X[0] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(2580.8236536430836, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2693.955649419219, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3061.634635691658, 2840.3100000000004, 'X[3] <= 9.081\ngini = 0.184\nsamples = 78\nvalue = [70, 8]'),
#  Text(2920.2196409714893, 2541.33, 'X[3] <= 7.24\ngini = 0.043\nsamples = 46\nvalue = [45, 1]'),
#  Text(2863.6536430834217, 2242.3500000000004, 'X[2] <= 29.85\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(2807.087645195354, 1943.37, 'gini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(2920.2196409714893, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2976.7856388595565, 2242.3500000000004, 'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(3203.049630411827, 2541.33, 'X[3] <= 15.373\ngini = 0.342\nsamples = 32\nvalue = [25, 7]'),
#  Text(3089.9176346356917, 2242.3500000000004, 'X[3] <= 15.148\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(3033.351636747624, 1943.37, 'X[3] <= 14.16\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(2976.7856388595565, 1644.3900000000003, 'X[3] <= 13.431\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(2920.2196409714893, 1345.4099999999999, 'X[2] <= 29.85\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(2863.6536430834217, 1046.4300000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2976.7856388595565, 1046.4300000000003, 'X[0] <= 2.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(2920.2196409714893, 747.4499999999998, 'X[2] <= 30.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(2863.6536430834217, 448.47000000000025, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2976.7856388595565, 448.47000000000025, 'X[3] <= 11.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(2920.2196409714893, 149.48999999999978, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3033.351636747624, 149.48999999999978, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3033.351636747624, 747.4499999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3033.351636747624, 1345.4099999999999, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3089.9176346356917, 1644.3900000000003, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3146.4836325237593, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3316.181626187962, 2242.3500000000004, 'X[3] <= 46.75\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(3259.6156282998945, 1943.37, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(3372.7476240760298, 1943.37, 'X[3] <= 63.023\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(3316.181626187962, 1644.3900000000003, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3429.3136219640974, 1644.3900000000003, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(3075.776135163675, 4335.21, 'X[3] <= 7.875\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(3019.2101372756074, 4036.2300000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3132.3421330517426, 4036.2300000000005, 'X[3] <= 20.925\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(3019.2101372756074, 3737.25, 'X[3] <= 8.144\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(2962.64413938754, 3438.2700000000004, 'X[3] <= 7.91\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(2906.078141499472, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3019.2101372756074, 3139.29, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(3075.776135163675, 3438.2700000000004, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3245.474128827878, 3737.25, 'X[3] <= 64.998\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(3188.9081309398102, 3438.2700000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3302.0401267159455, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3754.568109820486, 4634.1900000000005, 'X[2] <= 61.5\ngini = 0.082\nsamples = 70\nvalue = [67, 3]'),
#  Text(3641.4361140443507, 4335.21, 'X[2] <= 39.5\ngini = 0.06\nsamples = 65\nvalue = [63, 2]'),
#  Text(3584.870116156283, 4036.2300000000005, 'X[2] <= 38.5\ngini = 0.102\nsamples = 37\nvalue = [35, 2]'),
#  Text(3471.738120380148, 3737.25, 'X[3] <= 12.938\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(3415.1721224920802, 3438.2700000000004, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(3528.3041182682155, 3438.2700000000004, 'X[3] <= 14.275\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(3471.738120380148, 3139.29, 'X[2] <= 35.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(3415.1721224920802, 2840.3100000000004, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(3528.3041182682155, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3584.870116156283, 3139.29, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(3698.0021119324183, 3737.25, 'X[3] <= 10.463\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(3641.4361140443507, 3438.2700000000004, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(3754.568109820486, 3438.2700000000004, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3698.0021119324183, 4036.2300000000005, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(3867.700105596621, 4335.21, 'X[2] <= 63.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(3811.1341077085535, 4036.2300000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3924.2661034846888, 4036.2300000000005, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(5075.030623020064, 5531.13, 'X[0] <= 2.5\ngini = 0.387\nsamples = 225\nvalue = [59, 166]'),
#  Text(4221.237592397044, 5232.150000000001, 'X[2] <= 2.5\ngini = 0.094\nsamples = 121\nvalue = [6, 115]'),
#  Text(4037.398099260824, 4933.17, 'X[3] <= 88.775\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(3980.8321013727564, 4634.1900000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4093.9640971488916, 4634.1900000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4405.077085533263, 4933.17, 'X[3] <= 22.0\ngini = 0.081\nsamples = 119\nvalue = [5, 114]'),
#  Text(4207.096092925027, 4634.1900000000005, 'X[2] <= 53.5\ngini = 0.204\nsamples = 26\nvalue = [3, 23]'),
#  Text(4150.530095036959, 4335.21, 'X[3] <= 20.25\ngini = 0.147\nsamples = 25\nvalue = [2, 23]'),
#  Text(4037.398099260824, 4036.2300000000005, 'X[2] <= 25.5\ngini = 0.083\nsamples = 23\nvalue = [1, 22]'),
#  Text(3980.8321013727564, 3737.25, 'X[2] <= 22.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(3924.2661034846888, 3438.2700000000004, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(4037.398099260824, 3438.2700000000004, 'X[3] <= 15.875\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(3980.8321013727564, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4093.9640971488916, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4093.9640971488916, 3737.25, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(4263.662090813094, 4036.2300000000005, 'X[2] <= 28.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4207.096092925027, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4320.228088701162, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4263.662090813094, 4335.21, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4603.0580781415, 4634.1900000000005, 'X[3] <= 149.035\ngini = 0.042\nsamples = 93\nvalue = [2, 91]'),
#  Text(4433.360084477297, 4335.21, 'X[2] <= 49.5\ngini = 0.025\nsamples = 80\nvalue = [1, 79]'),
#  Text(4376.79408658923, 4036.2300000000005, 'gini = 0.0\nsamples = 67\nvalue = [0, 67]'),
#  Text(4489.926082365365, 4036.2300000000005, 'X[2] <= 50.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(4433.360084477297, 3737.25, 'X[3] <= 27.356\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4376.79408658923, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4489.926082365365, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4546.4920802534325, 3737.25, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(4772.756071805702, 4335.21, 'X[3] <= 152.506\ngini = 0.142\nsamples = 13\nvalue = [1, 12]'),
#  Text(4716.190073917635, 4036.2300000000005, 'X[2] <= 23.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4659.624076029568, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4772.756071805702, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4829.32206969377, 4036.2300000000005, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(5928.823653643084, 5232.150000000001, 'X[3] <= 24.808\ngini = 0.5\nsamples = 104\nvalue = [53, 51]'),
#  Text(5472.760295670539, 4933.17, 'X[3] <= 7.888\ngini = 0.487\nsamples = 86\nvalue = [36, 50]'),
#  Text(5055.58606124604, 4634.1900000000005, 'X[2] <= 30.1\ngini = 0.366\nsamples = 29\nvalue = [7, 22]'),
#  Text(4999.0200633579725, 4335.21, 'X[3] <= 6.987\ngini = 0.302\nsamples = 27\nvalue = [5, 22]'),
#  Text(4942.454065469905, 4036.2300000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5055.58606124604, 4036.2300000000005, 'X[2] <= 20.0\ngini = 0.26\nsamples = 26\nvalue = [4, 22]'),
#  Text(4999.0200633579725, 3737.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(5112.152059134108, 3737.25, 'X[2] <= 21.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(4999.0200633579725, 3438.2700000000004, 'X[3] <= 7.7\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(4942.454065469905, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5055.58606124604, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5225.284054910243, 3438.2700000000004, 'X[2] <= 23.5\ngini = 0.278\nsamples = 18\nvalue = [3, 15]'),
#  Text(5168.718057022175, 3139.29, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(5281.850052798311, 3139.29, 'X[2] <= 25.5\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(5225.284054910243, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5338.416050686378, 2840.3100000000004, 'X[3] <= 7.681\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(5225.284054910243, 2541.33, 'X[3] <= 7.429\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(5168.718057022175, 2242.3500000000004, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(5281.850052798311, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5451.548046462513, 2541.33, 'X[3] <= 7.769\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(5394.982048574446, 2242.3500000000004, 'X[3] <= 7.744\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(5338.416050686378, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(5451.548046462513, 1943.37, 'gini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(5508.114044350581, 2242.3500000000004, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(5112.152059134108, 4335.21, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(5889.934530095037, 4634.1900000000005, 'X[2] <= 16.0\ngini = 0.5\nsamples = 57\nvalue = [29, 28]'),
#  Text(5621.246040126716, 4335.21, 'X[3] <= 20.167\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(5564.680042238649, 4036.2300000000005, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(5677.812038014784, 4036.2300000000005, 'X[3] <= 21.55\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(5621.246040126716, 3737.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(5734.3780359028515, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6158.623020063358, 4335.21, 'X[3] <= 14.873\ngini = 0.485\nsamples = 46\nvalue = [27, 19]'),
#  Text(5904.076029567054, 4036.2300000000005, 'X[2] <= 55.0\ngini = 0.33\nsamples = 24\nvalue = [19, 5]'),
#  Text(5847.510031678987, 3737.25, 'X[3] <= 12.767\ngini = 0.287\nsamples = 23\nvalue = [19, 4]'),
#  Text(5790.944033790919, 3438.2700000000004, 'X[2] <= 19.0\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(5734.3780359028515, 3139.29, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5847.510031678987, 3139.29, 'X[3] <= 10.825\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(5790.944033790919, 2840.3100000000004, 'X[2] <= 30.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(5677.812038014784, 2541.33, 'X[3] <= 7.988\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(5621.246040126716, 2242.3500000000004, 'X[2] <= 26.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(5564.680042238649, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(5677.812038014784, 1943.37, 'X[2] <= 27.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5621.246040126716, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5734.3780359028515, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5734.3780359028515, 2242.3500000000004, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(5904.076029567054, 2541.33, 'X[3] <= 9.135\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5847.510031678987, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5960.642027455122, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(5904.076029567054, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(5904.076029567054, 3438.2700000000004, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(5960.642027455122, 3737.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6413.170010559663, 4036.2300000000005, 'X[2] <= 21.0\ngini = 0.463\nsamples = 22\nvalue = [8, 14]'),
#  Text(6356.604012671595, 3737.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(6469.7360084477305, 3737.25, 'X[2] <= 38.5\ngini = 0.42\nsamples = 20\nvalue = [6, 14]'),
#  Text(6413.170010559663, 3438.2700000000004, 'X[3] <= 18.629\ngini = 0.388\nsamples = 19\nvalue = [5, 14]'),
#  Text(6300.038014783528, 3139.29, 'X[3] <= 17.7\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(6243.47201689546, 2840.3100000000004, 'X[3] <= 15.675\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(6130.340021119325, 2541.33, 'X[2] <= 30.85\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(6073.774023231257, 2242.3500000000004, 'X[3] <= 15.373\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(6017.20802534319, 1943.37, 'X[2] <= 29.35\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(5960.642027455122, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6073.774023231257, 1644.3900000000003, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6130.340021119325, 1943.37, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(6186.906019007392, 2242.3500000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6356.604012671595, 2541.33, 'X[2] <= 27.85\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(6300.038014783528, 2242.3500000000004, 'X[2] <= 25.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(6243.47201689546, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6356.604012671595, 1943.37, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6413.170010559663, 2242.3500000000004, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(6356.604012671595, 2840.3100000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6526.302006335798, 3139.29, 'X[3] <= 23.35\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(6469.7360084477305, 2840.3100000000004, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(6582.868004223865, 2840.3100000000004, 'X[3] <= 23.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(6526.302006335798, 2541.33, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6639.434002111932, 2541.33, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6526.302006335798, 3438.2700000000004, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(6384.887011615629, 4933.17, 'X[2] <= 7.0\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(6328.321013727561, 4634.1900000000005, 'X[2] <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(6271.755015839493, 4335.21, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(6384.887011615629, 4335.21, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(6441.453009503696, 4634.1900000000005, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]')]

# %% [markdown]
# <b>Build a text report showing the rules of the Decision Tree model.</b>

# %%
print(tree.export_text(model))
# Out:
# |--- feature_1 <= 1.50
# |   |--- feature_2 <= 12.50
# |   |   |--- feature_0 <= 2.50
# |   |   |   |--- class: 1
# |   |   |--- feature_0 >  2.50
# |   |   |   |--- feature_3 <= 20.83
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  20.83
# |   |   |   |   |--- class: 0
# |   |--- feature_2 >  12.50
# |   |   |--- feature_0 <= 1.50
# |   |   |   |--- feature_2 <= 53.00
# |   |   |   |   |--- feature_3 <= 25.94
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_3 >  25.94
# |   |   |   |   |   |--- feature_3 <= 27.14
# |   |   |   |   |   |   |--- feature_2 <= 32.35
# |   |   |   |   |   |   |   |--- feature_2 <= 28.85
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  28.85
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  32.35
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  27.14
# |   |   |   |   |   |   |--- feature_3 <= 379.93
# |   |   |   |   |   |   |   |--- feature_3 <= 134.64
# |   |   |   |   |   |   |   |   |--- feature_3 <= 109.89
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 77.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 28.85
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  28.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  77.79
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  47.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  109.89
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  134.64
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  379.93
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  53.00
# |   |   |   |   |--- feature_2 <= 75.50
# |   |   |   |   |   |--- feature_3 <= 35.08
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  35.08
# |   |   |   |   |   |   |--- feature_3 <= 42.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_3 >  42.50
# |   |   |   |   |   |   |   |--- feature_3 <= 78.24
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  78.24
# |   |   |   |   |   |   |   |   |--- feature_3 <= 96.24
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  96.24
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  75.50
# |   |   |   |   |   |--- class: 1
# |   |   |--- feature_0 >  1.50
# |   |   |   |--- feature_2 <= 32.50
# |   |   |   |   |--- feature_2 <= 31.50
# |   |   |   |   |   |--- feature_2 <= 17.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  17.50
# |   |   |   |   |   |   |--- feature_2 <= 20.25
# |   |   |   |   |   |   |   |--- feature_3 <= 7.91
# |   |   |   |   |   |   |   |   |--- feature_2 <= 19.50
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  19.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.14
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.14
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.54
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.91
# |   |   |   |   |   |   |   |   |--- feature_3 <= 8.10
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  8.10
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.34
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.34
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  20.25
# |   |   |   |   |   |   |   |--- feature_3 <= 7.23
# |   |   |   |   |   |   |   |   |--- feature_2 <= 28.35
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.01
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.01
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.13
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  28.35
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  7.23
# |   |   |   |   |   |   |   |   |--- feature_2 <= 28.75
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_2 >  28.75
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 29.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.97
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  29.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |--- feature_2 >  31.50
# |   |   |   |   |   |--- feature_3 <= 7.88
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  7.88
# |   |   |   |   |   |   |--- feature_3 <= 20.93
# |   |   |   |   |   |   |   |--- feature_3 <= 8.14
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.91
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.91
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  8.14
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  20.93
# |   |   |   |   |   |   |   |--- feature_3 <= 65.00
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  65.00
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_2 >  32.50
# |   |   |   |   |--- feature_2 <= 61.50
# |   |   |   |   |   |--- feature_2 <= 39.50
# |   |   |   |   |   |   |--- feature_2 <= 38.50
# |   |   |   |   |   |   |   |--- feature_3 <= 12.94
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  12.94
# |   |   |   |   |   |   |   |   |--- feature_3 <= 14.28
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 35.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  35.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  14.28
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  38.50
# |   |   |   |   |   |   |   |--- feature_3 <= 10.46
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_3 >  10.46
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_2 >  39.50
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  61.50
# |   |   |   |   |   |--- feature_2 <= 63.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  63.50
# |   |   |   |   |   |   |--- class: 0
# |--- feature_1 >  1.50
# |   |--- feature_0 <= 2.50
# |   |   |--- feature_2 <= 2.50
# |   |   |   |--- feature_3 <= 88.78
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_3 >  88.78
# |   |   |   |   |--- class: 0
# |   |   |--- feature_2 >  2.50
# |   |   |   |--- feature_3 <= 22.00
# |   |   |   |   |--- feature_2 <= 53.50
# |   |   |   |   |   |--- feature_3 <= 20.25
# |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |--- feature_2 <= 22.50
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  22.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 15.88
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  15.88
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  20.25
# |   |   |   |   |   |   |--- feature_2 <= 28.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  28.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  53.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  22.00
# |   |   |   |   |--- feature_3 <= 149.04
# |   |   |   |   |   |--- feature_2 <= 49.50
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  49.50
# |   |   |   |   |   |   |--- feature_2 <= 50.50
# |   |   |   |   |   |   |   |--- feature_3 <= 27.36
# |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  27.36
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  50.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_3 >  149.04
# |   |   |   |   |   |--- feature_3 <= 152.51
# |   |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  152.51
# |   |   |   |   |   |   |--- class: 1
# |   |--- feature_0 >  2.50
# |   |   |--- feature_3 <= 24.81
# |   |   |   |--- feature_3 <= 7.89
# |   |   |   |   |--- feature_2 <= 30.10
# |   |   |   |   |   |--- feature_3 <= 6.99
# |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |--- feature_3 >  6.99
# |   |   |   |   |   |   |--- feature_2 <= 20.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |--- feature_2 >  20.00
# |   |   |   |   |   |   |   |--- feature_2 <= 21.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 7.70
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_3 >  7.70
# |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |--- feature_2 >  21.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 23.50
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  23.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 7.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  7.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |--- feature_2 >  30.10
# |   |   |   |   |   |--- class: 0
# |   |   |   |--- feature_3 >  7.89
# |   |   |   |   |--- feature_2 <= 16.00
# |   |   |   |   |   |--- feature_3 <= 20.17
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  20.17
# |   |   |   |   |   |   |--- feature_3 <= 21.55
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_3 >  21.55
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_2 >  16.00
# |   |   |   |   |   |--- feature_3 <= 14.87
# |   |   |   |   |   |   |--- feature_2 <= 55.00
# |   |   |   |   |   |   |   |--- feature_3 <= 12.77
# |   |   |   |   |   |   |   |   |--- feature_2 <= 19.00
# |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |--- feature_2 >  19.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 10.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  10.82
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_3 >  12.77
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  55.00
# |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_3 >  14.87
# |   |   |   |   |   |   |--- feature_2 <= 21.00
# |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |--- feature_2 >  21.00
# |   |   |   |   |   |   |   |--- feature_2 <= 38.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 18.63
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 17.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.68
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  17.70
# |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |--- feature_3 >  18.63
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 23.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  23.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 23.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  23.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |   |   |--- feature_2 >  38.50
# |   |   |   |   |   |   |   |   |--- class: 0
# |   |   |--- feature_3 >  24.81
# |   |   |   |--- feature_2 <= 7.00
# |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |--- class: 0
# |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  7.00
# |   |   |   |   |--- class: 0

# %% [markdown]
# [<b> Minimal Cost-Complexity Pruning</b>](https://scikit-learn.org/stable/auto_examples/tree/plot_cost_complexity_pruning.html)
# Minimal cost-complexity pruning is an algorithm used to prune a tree to avoid over-fitting. This pruning technique is parameterized by the cost complexity parameter, ccp_alpha. Greater values of ccp_alpha increase the number of nodes pruned.
# ccp_alpha : (non-negative float, default=0.0)
# Complexity parameter used for Minimal Cost-Complexity Pruning. The subtree with the largest cost complexity that is smaller than ccp_alpha will be chosen. By default, no pruning is performed.

# %%
path = model.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities

# %%
ccp_alphas
# Out:
# array([0.        , 0.00017511, 0.00057326, 0.00063696, 0.00073569,
#        0.00095119, 0.00097281, 0.00098092, 0.00101659, 0.00105601,
#        0.00106859, 0.00107009, 0.00107009, 0.00114653, 0.00120385,
#        0.00128411, 0.00133761, 0.00137583, 0.00137583, 0.00140202,
#        0.00144462, 0.00145313, 0.00145921, 0.00148166, 0.00151877,
#        0.0015287 , 0.00154162, 0.00156085, 0.00169177, 0.00171215,
#        0.00178348, 0.00180578, 0.00180882, 0.00190393, 0.00191088,
#        0.00192616, 0.00199546, 0.00208459, 0.00210127, 0.00232123,
#        0.00254   , 0.00267523, 0.00272878, 0.00288888, 0.00288925,
#        0.0029402 , 0.00340561, 0.00352868, 0.00733777, 0.00856073,
#        0.01355733, 0.01555617, 0.03899866, 0.14272265])

# %% [markdown]
# DecisionTreeClassifier.cost_complexity_pruning_path : returns the effective alphas and the corresponding total leaf impurities at each step of the pruning process. As alpha increases, more of the tree is pruned, which increases the total impurity of its leaves.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# <b>For each value of ccp_alpha, train a DecisionTree model and store it in models.</b>

# %%
models = []
for ccp_alpha in ccp_alphas:
    model = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
    model.fit(X_train, y_train)
    models.append(model)
print("Number of nodes in the last tree is: {} with ccp_alpha: {}".format(
      models[-1].tree_.node_count, ccp_alphas[-1]))
# Out:
# Number of nodes in the last tree is: 1 with ccp_alpha: 0.14272265274004609

# %% [markdown]
# <b>For all the models trained for different values of ccp_alpha, find training and testing accuracy and plot it.</b>

# %%
# Calculate train and test accuracy of all the models
train_scores = [model.score(X_train, y_train) for model in models]
test_scores = [model.score(X_test, y_test) for model in models]

# plot training and testingaccuracy
fig, ax = plt.subplots(figsize = (18,6))
ax.set_xlabel("alpha", fontsize = 14)
ax.set_ylabel("Accuracy", fontsize = 14)
ax.set_title("Accuracy vs alpha for training and testing sets", fontsize = 16)
ax.plot(ccp_alphas, train_scores, marker='o', label="train",
        drawstyle="steps-post")
ax.plot(ccp_alphas, test_scores, marker='o', label="test",
        drawstyle="steps-post")
ax.legend()
plt.show()

# %% [markdown]
#  - From the above plot, it is clear that around 0.003 ccp_alpha, model accuracy for test data is highest.
#  - It can also be noted that near 0.003 ccp_alpha, training and testing accuracies are almost equal which means model is not over-fitting.

# %% [markdown]
# <b> Train Final Decision tree model with the selected value of ccp_alpha.</b>

# %%
model = DecisionTreeClassifier(random_state=0, ccp_alpha=0.003)
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.003, random_state=0)

# %%
# Make predictions for testing data
pred=model.predict(X_test)

# Import accuracy_score, which also calculates the accuracy of predictions
from sklearn.metrics import accuracy_score
print('Model accuracy after post-pruning :',round(accuracy_score(y_test, pred),3))
# Out:
# Model accuracy after post-pruning : 0.81

# %% [markdown]
# The model accuracy after post pruning increased. This shows that without post pruning, our initial decisionTree model was over-fitting on the training data.

# %% [markdown]
# <b> Lets visualize our final DecisonTree model to observe the effect of post-pruning. </b>

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model,filled=True)
# Out:
# [Text(478.2857142857143, 504.7714285714286, 'X[1] <= 1.5\ngini = 0.477\nsamples = 623\nvalue = [378, 245]'),
#  Text(298.92857142857144, 427.11428571428576, 'X[2] <= 13.0\ngini = 0.3\nsamples = 386\nvalue = [315, 71]'),
#  Text(119.57142857142857, 349.4571428571429, 'X[3] <= 18.769\ngini = 0.494\nsamples = 27\nvalue = [12, 15]'),
#  Text(59.785714285714285, 271.8, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(179.35714285714286, 271.8, 'X[0] <= 2.5\ngini = 0.444\nsamples = 18\nvalue = [12, 6]'),
#  Text(119.57142857142857, 194.14285714285717, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(239.14285714285714, 194.14285714285717, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(478.2857142857143, 349.4571428571429, 'X[0] <= 1.5\ngini = 0.263\nsamples = 359\nvalue = [303, 56]'),
#  Text(418.5, 271.8, 'X[3] <= 26.144\ngini = 0.459\nsamples = 84\nvalue = [54, 30]'),
#  Text(358.7142857142857, 194.14285714285717, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(478.2857142857143, 194.14285714285717, 'X[2] <= 53.5\ngini = 0.476\nsamples = 77\nvalue = [47, 30]'),
#  Text(418.5, 116.48571428571432, 'X[2] <= 47.5\ngini = 0.494\nsamples = 63\nvalue = [35, 28]'),
#  Text(358.7142857142857, 38.82857142857142, 'gini = 0.475\nsamples = 54\nvalue = [33, 21]'),
#  Text(478.2857142857143, 38.82857142857142, 'gini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(538.0714285714286, 116.48571428571432, 'gini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(538.0714285714286, 271.8, 'gini = 0.171\nsamples = 275\nvalue = [249, 26]'),
#  Text(657.6428571428571, 427.11428571428576, 'X[0] <= 2.5\ngini = 0.39\nsamples = 237\nvalue = [63, 174]'),
#  Text(597.8571428571429, 349.4571428571429, 'gini = 0.104\nsamples = 127\nvalue = [7, 120]'),
#  Text(717.4285714285714, 349.4571428571429, 'X[3] <= 24.808\ngini = 0.5\nsamples = 110\nvalue = [56, 54]'),
#  Text(657.6428571428571, 271.8, 'X[2] <= 38.0\ngini = 0.487\nsamples = 93\nvalue = [39, 54]'),
#  Text(597.8571428571429, 194.14285714285717, 'gini = 0.476\nsamples = 87\nvalue = [34, 53]'),
#  Text(717.4285714285714, 194.14285714285717, 'gini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(777.2142857142857, 271.8, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]')]

# %% [markdown]
# <b>It can be observed that after post-pruning, the size of decision tree reduced.</b>
